# %%
factorial(20)
# Out:
# 2432902008176640000

# %%
f(x)=(1/(2-cos(x)))
ty(x)=f.taylor(x,1.0,3)
print(ty)
print(f(1.2))
print(ty(1.2).n())
# Out:
# x |--> 0.08076052068325706*(x - 1.0)^3 + 0.100872638092211*(x - 1.0)^2 - 0.3949237948187951*x + 1.0799971521448402
# 0.610633978656577
# 0.610769588051441

# %%
f(x)=sin(x)
ty1(x)=f.taylor(x,1.0,6)
p0=plot(f(x),(x,-3.0, 3.0))
p1=plot(ty1(x),(x,-3.0, 3.0),color='purple')
show(p1+p0)
print(ty1(x))
# Out:
# Graphics object consisting of 2 graphics primitives
# -0.001168709701122079*(x - 1.0)^6 + 0.004502519215567831*(x - 1.0)^5 + 0.03506129103366235*(x - 1.0)^4 - 0.09005038431135662*(x - 1.0)^3 - 0.4207354924039483*(x - 1.0)^2 + 0.5403023058681398*x + 0.30116867893975674
